# %%
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]='0'
os.environ["HF_HOME"]="~/codes/.cache/huggingface"

# %%
import pandas as pd
df = pd.read_csv('/home/teoaivalis/.cache/kagglehub/datasets/alexanderliao/artbench10/versions/2/ArtBench-10.csv')
#df['path'] = df.apply(lambda x: "../../codes/artbench/data/artbench-10-imagefolder/{}/{}".format(x['label'], x['name']), axis=1)
df['path'] = df.apply(lambda x: "/home/teoaivalis/neurips/artbench-merged/{}/{}".format(x['label'], x['name']), axis=1)
df.head()
# Out:
#                                             name              artist  \
# 0      frank-omeara_towards-night-and-winter.jpg        frank-omeara
# 1                 goldstein-grigoriy_morning.jpg  goldstein-grigoriy
# 2                 georges-lemmen_man-reading.jpg      georges-lemmen
# 3       theodor-aman_port-of-constantza-1882.jpg        theodor-aman
# 4  niccolo-cannicci_il-passo-della-futa-1914.jpg    niccolo-cannicci
#
#                                                  url  is_public_domain  \
# 0  https://uploads5.wikiart.org/00316/images/fran...              True
# 1  https://uploads5.wikiart.org/images/grigoriy-g...              True
# 2  https://uploads6.wikiart.org/images/georges-le...              True
# 3  https://uploads6.wikiart.org/images/theodor-am...              True
# 4  https://uploads3.wikiart.org/images/niccolo-ca...              True
#
#    length  width          label  split  cifar_index  \
# 0     800    657  impressionism  train        43186
# 1     521    499  impressionism  train        41151
# 2     800    612  impressionism  train         9754
# 3     560    336  impressionism  train        44244
# 4    2400   2322  impressionism  train        46885
#
#                                                 path
# 0  /home/teoaivalis/neurips/artbench-merged/impre...
# 1  /home/teoaivalis/neurips/artbench-merged/impre...
# 2  /home/teoaivalis/neurips/artbench-merged/impre...
# 3  /home/teoaivalis/neurips/artbench-merged/impre...
# 4  /home/teoaivalis/neurips/artbench-merged/impre...

# %%
df['label'].unique()
# Out:
# array(['impressionism', 'romanticism', 'expressionism', 'surrealism',
#        'art_nouveau', 'renaissance', 'realism', 'post_impressionism',
#        'baroque', 'ukiyo_e'], dtype=object)

# %%
df_val = df[(df['label'].isin(['post_impressionism', 'ukiyo_e'])) & (df['split']=='test')]
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 42015 to 59997
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2000 non-null   object
#  1   artist            2000 non-null   object
#  2   url               2000 non-null   object
#  3   is_public_domain  2000 non-null   bool
#  4   length            2000 non-null   int64
#  5   width             2000 non-null   int64
#  6   label             2000 non-null   object
#  7   split             2000 non-null   object
#  8   cifar_index       2000 non-null   int64
#  9   path              2000 non-null   object
# dtypes: bool(1), int64(3), object(6)
# memory usage: 158.2+ KB

# %%
df_val.head()
# Out:
#                                                     name  \
# 42015  santiago-rusinol_terraced-garden-in-mallorca-1...
# 42018             henri-edmond-cross_land-by-the-sea.jpg
# 42026                             javad-hamidi_mader.jpg
# 42044  grace-cossington-smith_figure-through-flowers-...
# 42058                theo-van-doesburg_dunes-and-sea.jpg
#
#                        artist  \
# 42015        santiago-rusinol
# 42018      henri-edmond-cross
# 42026            javad-hamidi
# 42044  grace-cossington-smith
# 42058       theo-van-doesburg
#
#                                                      url  is_public_domain  \
# 42015  https://uploads2.wikiart.org/images/santiago-r...              True
# 42018  https://uploads5.wikiart.org/images/henri-edmo...              True
# 42026  https://uploads1.wikiart.org/00136/images/java...             False
# 42044  https://uploads3.wikiart.org/images/grace-coss...             False
# 42058  https://uploads2.wikiart.org/images/theo-van-d...              True
#
#        length  width               label split  cifar_index  \
# 42015     799    598  post_impressionism  test         1970
# 42018    1133    788  post_impressionism  test         9785
# 42026    1855   1295  post_impressionism  test         7520
# 42044     600    445  post_impressionism  test          853
# 42058    1200   1086  post_impressionism  test         3904
#
#                                                     path
# 42015  /home/teoaivalis/neurips/artbench-merged/post_...
# 42018  /home/teoaivalis/neurips/artbench-merged/post_...
# 42026  /home/teoaivalis/neurips/artbench-merged/post_...
# 42044  /home/teoaivalis/neurips/artbench-merged/post_...
# 42058  /home/teoaivalis/neurips/artbench-merged/post_...

# %%
from sklearn.model_selection import train_test_split

# %%
df_val, _ = train_test_split(df_val, train_size=1000, random_state=42, stratify=df_val['label'])
df_val['label'].value_counts()
# Out:
# label
# ukiyo_e               500
# post_impressionism    500
# Name: count, dtype: int64

# %%
df_val.head()
# Out:
#                                         name               artist  \
# 58519               utagawa-sadahide_171.jpg     utagawa-sadahide
# 45032  albert-marquet_the-coffeepot-1902.jpg       albert-marquet
# 42761           mario-zanini_lerici-1950.jpg         mario-zanini
# 58081                utagawa-toyoharu_56.jpg     utagawa-toyoharu
# 58630           tsukioka-yoshitoshi_3091.jpg  tsukioka-yoshitoshi
#
#                                                      url  is_public_domain  \
# 58519             https://ukiyo-e.org/image/mfa/sc166896              True
# 45032  https://uploads4.wikiart.org/images/albert-mar...              True
# 42761  https://uploads3.wikiart.org/images/mario-zani...             False
# 58081             https://ukiyo-e.org/image/mfa/sc209846              True
# 58630             https://ukiyo-e.org/image/mfa/sc137705              True
#
#        length  width               label split  cifar_index  \
# 58519    2000   1463             ukiyo_e  test         9493
# 45032    1234   1024  post_impressionism  test         1379
# 42761     512    399  post_impressionism  test          209
# 58081    2000   1426             ukiyo_e  test         8441
# 58630    1500    998             ukiyo_e  test         9759
#
#                                                     path
# 58519  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 45032  /home/teoaivalis/neurips/artbench-merged/post_...
# 42761  /home/teoaivalis/neurips/artbench-merged/post_...
# 58081  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 58630  /home/teoaivalis/neurips/artbench-merged/ukiyo...

# %%
import pickle

for i in [5000]:
    for j in [0.5]:
        filename = os.path.join('./data/indices/{}-{}/idx-val.pkl'.format(i, j))
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        
        with open(filename, 'wb') as handle:
            pickle.dump(df_val.index.to_list(), handle)

# %%
'post_impressionism'.replace("_", " ").lower()
# Out:
# 'post impressionism'

# %%
df_train = df[(df['label'].isin(['post_impressionism', 'ukiyo_e'])) & (df['split']=='train')]
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 42000 to 59999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              10000 non-null  object
#  1   artist            10000 non-null  object
#  2   url               10000 non-null  object
#  3   is_public_domain  10000 non-null  bool
#  4   length            10000 non-null  int64
#  5   width             10000 non-null  int64
#  6   label             10000 non-null  object
#  7   split             10000 non-null  object
#  8   cifar_index       10000 non-null  int64
#  9   path              10000 non-null  object
# dtypes: bool(1), int64(3), object(6)
# memory usage: 791.0+ KB

# %%
for path in df_val['path']:
    #print(path)
    if os.path.isfile(path):
        pass
    else:
        print(path)
        break

# %%
for path in df_train['path']:
    # print(path)
    if os.path.isfile(path):
        pass
    else:
        print(path)
        break

# %%
df_train['label'].unique()
# Out:
# array(['post_impressionism', 'ukiyo_e'], dtype=object)

# %%
df_train.head()
# Out:
#                                                     name  \
# 42000  henri-de-toulouse-lautrec_jane-avril-leaving-t...
# 42001        istvan-ilosvai-varga_green-quinces-1936.jpg
# 42002              robert-spencer_flowing-water-1924.jpg
# 42003           lois-mailou-jones_brother-brown-1931.jpg
# 42004                   louis-hayet_evening-in-paris.jpg
#
#                           artist  \
# 42000  henri-de-toulouse-lautrec
# 42001       istvan-ilosvai-varga
# 42002             robert-spencer
# 42003          lois-mailou-jones
# 42004                louis-hayet
#
#                                                      url  is_public_domain  \
# 42000  https://uploads1.wikiart.org/images/henri-de-t...              True
# 42001  https://uploads0.wikiart.org/images/istvan-ilo...             False
# 42002  https://uploads4.wikiart.org/images/robert-spe...              True
# 42003  https://uploads4.wikiart.org/00315/images/lois...             False
# 42004  https://uploads6.wikiart.org/00329/images/loui...              True
#
#        length  width               label  split  cifar_index  \
# 42000    3341   2536  post_impressionism  train        25579
# 42001     475    438  post_impressionism  train        44919
# 42002     879    749  post_impressionism  train        35092
# 42003     600    437  post_impressionism  train        20368
# 42004    2880   1953  post_impressionism  train        39730
#
#                                                     path
# 42000  /home/teoaivalis/neurips/artbench-merged/post_...
# 42001  /home/teoaivalis/neurips/artbench-merged/post_...
# 42002  /home/teoaivalis/neurips/artbench-merged/post_...
# 42003  /home/teoaivalis/neurips/artbench-merged/post_...
# 42004  /home/teoaivalis/neurips/artbench-merged/post_...

# %%
df_train.tail()
# Out:
#                                 name                 artist  \
# 59994              yoshifuji_128.jpg              yoshifuji
# 59995   utagawa-hiroshige-ii_579.jpg   utagawa-hiroshige-ii
# 59996    utagawa-hiroshige_11968.jpg      utagawa-hiroshige
# 59998    toyohara-chikanobu_3078.jpg     toyohara-chikanobu
# 59999  utagawa-hiroshige-iii_793.jpg  utagawa-hiroshige-iii
#
#                                                     url  is_public_domain  \
# 59994  https://ukiyo-e.org/image/famsf/5131162228180055              True
# 59995  https://ukiyo-e.org/image/famsf/5050161212750078              True
# 59996  https://ukiyo-e.org/image/famsf/5050161207490054              True
# 59998  https://ukiyo-e.org/image/famsf/7255324240550041              True
# 59999  https://ukiyo-e.org/image/famsf/7224328201820041              True
#
#        length  width    label  split  cifar_index  \
# 59994     900    629  ukiyo_e  train          462
# 59995     900    607  ukiyo_e  train        19424
# 59996    1220    825  ukiyo_e  train        48260
# 59998    1220    613  ukiyo_e  train        27420
# 59999    1220    675  ukiyo_e  train        27253
#
#                                                     path
# 59994  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 59995  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 59996  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 59998  /home/teoaivalis/neurips/artbench-merged/ukiyo...
# 59999  /home/teoaivalis/neurips/artbench-merged/ukiyo...

# %%
for i in [5000
         ]:
    for j in [0.5]:
        if i<len(df_train):
            df_train_, _ = train_test_split(df_train, train_size=i, 
                                        random_state=42, 
                                        stratify=df_train['label'])
        else:
            df_train_ = df_train.copy()
            
        print(len(df_train_))
        ####
        filename = os.path.join('./data/indices/{}-{}/idx-train.pkl'.format(i, j))
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        
        with open(filename, 'wb') as handle:
            pickle.dump(df_train_.index.to_list(), handle)
        ####
        count = 0
        ####
        for k in range(256):
            tmp, _ = train_test_split(df_train_, train_size=j, random_state=42+count+k, 
                                  stratify=df_train_['label']
                             )
            filename = os.path.join('./data/indices/{}-{}/lds-val/sub-idx-{}.pkl'.format(i, j, k))
            os.makedirs(os.path.dirname(filename), exist_ok=True)
            with open(filename, 'wb') as handle:
                pickle.dump(tmp.index.to_list(), handle)
            count = count+1
        print(count)
        ####
        for k in range(256):
            tmp, _ = train_test_split(df_train_, train_size=j, random_state=42+count+k, 
                                  stratify=df_train_['label']
                             )
            filename = os.path.join('./data/indices/{}-{}/lds-test/sub-idx-{}.pkl'.format(i, j, k))
            os.makedirs(os.path.dirname(filename), exist_ok=True)
            with open(filename, 'wb') as handle:
                pickle.dump(tmp.index.to_list(), handle)
            count = count+1 
        print(count)
        ####
        for k in range(1024):
            tmp, _ = train_test_split(df_train_, train_size=j, random_state=42+count+k, 
                                  stratify=df_train_['label']
                             )
            filename = os.path.join('./data/indices/{}-{}/retrain/sub-idx-{}.pkl'.format(i, j, k))
            os.makedirs(os.path.dirname(filename), exist_ok=True)
            with open(filename, 'wb') as handle:
                pickle.dump(tmp.index.to_list(), handle)
            count = count+1   
        print(count)
# Out:
# 5000
# 256
# 512
# 1536

# %%
with open('./data/indices/5000-0.5/idx-train.pkl', 'rb')  as handle:
    idx_train = pickle.load(handle)
len(idx_train)
# Out:
# 5000

# %%
with open('./data/indices/5000-0.5/idx-val.pkl', 'rb')  as handle:
    idx_val = pickle.load(handle)
len(idx_val)
# Out:
# 1000

# %%
from datasets import DatasetDict, Dataset, load_dataset, Image

train_dataset = Dataset.from_dict({"image": df.loc[idx_train]['path'].tolist(),
                                   "label": df.loc[idx_train]['label'].tolist(),
                                  }).cast_column("image", Image())
train_dataset[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
train_dataset[1]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
train_dataset[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>,
#  'label': 'post_impressionism'}

# %%
dataset = DatasetDict({"train":train_dataset,
                       })
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 5000
#     })
# })

# %%
val_dataset = Dataset.from_dict({"image": df.loc[idx_val]['path'].tolist(),
                                   "label": df.loc[idx_val]['label'].tolist(),
                                  }).cast_column("image", Image())
val_dataset[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
val_dataset[1]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
val_dataset
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 1000
# })
